# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.18.0

# %%
## import basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
## Divide the dataset into dependent and independent feature
X = df.iloc[:,3:13]
y = df.iloc[:,13]

# %%
X.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# 2          1               0        113931.57
# 3          0               0         93826.63
# 4          1               1         79084.10

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %%
## feature Engineering
geography = pd.get_dummies(X['Geography'],drop_first=True).astype(int)
gender = pd.get_dummies(X['Gender'],drop_first=True).astype(int)

# %%
geography
# Out:
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [10000 rows x 2 columns]

# %%
## concatenate these variable with dataframe
X = X.drop(['Geography','Gender'],axis=1)
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary
# 0               1        101348.88
# 1               1        112542.58
# 2               0        113931.57
# 3               0         93826.63
# 4               1         79084.10

# %%
X = pd.concat([X,geography,gender],axis=1)

# %%
#Sliptting the dataset into training set and test set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
## Features scaling
import sklearn
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %%
X_test
# Out:
# array([[-0.55204276, -0.36890377,  1.04473698, ...,  1.75486502,
#         -0.57369368, -1.09168714],
#        [-1.31490297,  0.10961719, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        [ 0.57162971,  0.30102557,  1.04473698, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        ...,
#        [-0.74791227, -0.27319958, -1.37744033, ..., -0.5698444 ,
#          1.74309049,  0.91601335],
#        [-0.00566991, -0.46460796, -0.33936434, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-0.79945688, -0.84742473,  1.04473698, ...,  1.75486502,
#         -0.57369368,  0.91601335]])

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
## Part 2 now lets create an ANN
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU,PReLU,ELU,ReLU
from tensorflow.keras.layers import Dropout

# %%
 ### Lets initialixe the ANN
 classifier = Sequential()

# %%
## Adding the input layer
classifier.add(Dense(units=11,activation='relu'))

# %%
## Adding the first hidden layer
classifier.add(Dense(units=7,activation='relu'))
classifier.add(Dropout(0.2))

# %%
## Adding the secound hidden layer
classifier.add(Dense(units=6,activation='relu'))
classifier.add(Dropout(0.3))

# %%
## Adding the output layer
classifier.add(Dense(1,activation='sigmoid'))

# %%
import tensorflow
opt = tensorflow.keras.optimizers.Adam(learning_rate=0.01)
classifier.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])

# OR

# classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
## Early stopping
import tensorflow as tf
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0.0001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
    start_from_epoch=2,
)

# %%
model_histroy = classifier.fit(X_train,y_train,validation_split=0.33,batch_size=10,epochs=1000,callbacks=early_stop)
# Out:
# Epoch 1/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8173 - loss: 0.4652 - val_accuracy: 0.8557 - val_loss: 0.3726
# Epoch 2/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8548 - loss: 0.3620 - val_accuracy: 0.8519 - val_loss: 0.3693
# Epoch 3/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.8496 - loss: 0.3723 - val_accuracy: 0.8542 - val_loss: 0.3695
# Epoch 4/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8520 - loss: 0.3709 - val_accuracy: 0.8519 - val_loss: 0.3731
# Epoch 5/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8427 - loss: 0.3740 - val_accuracy: 0.8569 - val_loss: 0.3640
# Epoch 6/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8619 - loss: 0.3560 - val_accuracy: 0.8580 - val_loss: 0.3643
# Epoch 7/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8493 - loss: 0.3678 - val_accuracy: 0.8550 - val_loss: 0.3658
# Epoch 8/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8599 - loss: 0.3545 - val_accuracy: 0.8512 - val_loss: 0.3736
# Epoch 9/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8506 - loss: 0.3634 - val_accuracy: 0.8425 - val_loss: 0.3879
# Epoch 10/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8584 - loss: 0.3511 - val_accuracy: 0.8554 - val_loss: 0.3704
# Epoch 11/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8543 - loss: 0.3678 - val_accuracy: 0.8489 - val_loss: 0.3696
# Epoch 12/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8574 - loss: 0.3625 - val_accuracy: 0.8546 - val_loss: 0.3726
# Epoch 13/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8587 - loss: 0.3563 - val_accuracy: 0.8444 - val_loss: 0.3736
# Epoch 14/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8498 - loss: 0.3640 - val_accuracy: 0.8398 - val_loss: 0.3979
# Epoch 15/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8452 - loss: 0.3761 - val_accuracy: 0.8542 - val_loss: 0.3655
# Epoch 16/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8498 - loss: 0.3704 - val_accuracy: 0.8538 - val_loss: 0.3674
# Epoch 17/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8565 - loss: 0.3584 - val_accuracy: 0.8455 - val_loss: 0.3738
# Epoch 18/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8408 - loss: 0.3758 - val_accuracy: 0.8565 - val_loss: 0.3611
# Epoch 19/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8587 - loss: 0.3553 - val_accuracy: 0.8542 - val_loss: 0.3662
# Epoch 20/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8596 - loss: 0.3514 - val_accuracy: 0.8523 - val_loss: 0.3655
# Epoch 21/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8648 - loss: 0.3423 - val_accuracy: 0.8542 - val_loss: 0.3627
# Epoch 22/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8582 - loss: 0.3575 - val_accuracy: 0.8417 - val_loss: 0.3702
# Epoch 23/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8606 - loss: 0.3362 - val_accuracy: 0.8554 - val_loss: 0.3628
# Epoch 24/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8495 - loss: 0.3566 - val_accuracy: 0.8557 - val_loss: 0.3638
# Epoch 25/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8593 - loss: 0.3471 - val_accuracy: 0.8497 - val_loss: 0.3825
# Epoch 26/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8536 - loss: 0.3590 - val_accuracy: 0.8459 - val_loss: 0.3673
# Epoch 27/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8609 - loss: 0.3496 - val_accuracy: 0.8485 - val_loss: 0.3772
# Epoch 28/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8584 - loss: 0.3536 - val_accuracy: 0.8383 - val_loss: 0.3828
# Epoch 29/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8688 - loss: 0.3433 - val_accuracy: 0.8523 - val_loss: 0.3655
# Epoch 30/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8564 - loss: 0.3449 - val_accuracy: 0.8512 - val_loss: 0.3726
# Epoch 31/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8464 - loss: 0.3675 - val_accuracy: 0.8497 - val_loss: 0.3733
# Epoch 32/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8577 - loss: 0.3440 - val_accuracy: 0.8542 - val_loss: 0.3646
# Epoch 33/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8666 - loss: 0.3524 - val_accuracy: 0.8338 - val_loss: 0.3775
# Epoch 34/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8575 - loss: 0.3621 - val_accuracy: 0.8455 - val_loss: 0.3764
# Epoch 35/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8544 - loss: 0.3578 - val_accuracy: 0.8542 - val_loss: 0.3702
# Epoch 36/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8504 - loss: 0.3592 - val_accuracy: 0.8516 - val_loss: 0.3659
# Epoch 37/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8692 - loss: 0.3331 - val_accuracy: 0.8387 - val_loss: 0.3877
# Epoch 38/1000
# 536/536 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8500 - loss: 0.3670 - val_accuracy: 0.8576 - val_loss: 0.3645
# Epoch 38: early stopping

# %%
 model_histroy.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# summarize the history for accuracy
plt.plot(model_histroy.history['accuracy'])
plt.plot(model_histroy.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(model_histroy.history['loss'])
plt.plot(model_histroy.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','test'], loc='upper left')
plt.show()

# %%
# part -3 Making the prediction and evaluating the model

#predicting the test set result
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
## make the confusion martix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[1515,   80],
#        [ 209,  196]])

# %%
## Calculate the accuracy
from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred,y_test)
score
# Out:
# 0.8555

# %%
## Get the weights
classifier.get_weights()
# Out:
# [array([[ 0.5424155 ,  3.1627805 ,  0.01161034,  1.2945263 ,  0.1368532 ,
#           1.675454  ,  0.42269808, -0.0627104 , -0.8686542 ,  1.128208  ,
#          -0.5588679 ],
#         [-0.95977247, -0.8247546 ,  0.65666705, -1.5054871 ,  3.8739543 ,
#          -0.701294  , -2.51577   ,  3.6445692 , -2.415097  , -0.45663017,
#           0.26390535],
#         [-0.3132437 , -0.3643215 , -0.13058427,  1.0867153 ,  0.01500061,
#          -0.73986125,  0.23173131,  0.4148181 , -1.2519633 ,  0.18289119,
#           0.29120135],
#         [-3.8943222 , -2.0551696 ,  1.2080456 ,  2.8699222 , -1.6221331 ,
#          -2.1132288 , -0.2203913 ,  0.24523535, -0.02004624,  0.15912633,
#           1.6341205 ],
#         [ 1.5650492 ,  1.7356286 ,  5.2454295 ,  1.9834907 , -2.7404623 ,
#          -0.23612094,  1.6752712 ,  1.6065024 ,  1.8029279 ,  1.5265596 ,
#           1.4304625 ],
#         [-1.8277566 ,  1.6949651 , -0.13876623,  0.37035665, -0.31879988,
#          -0.7232982 , -0.6142831 , -0.09235937,  0.9293268 , -0.16580635,
#           0.60906374],
#         [ 0.9264858 ,  0.5449015 , -0.13728477,  1.471126  , -0.36230153,
#          -0.07817432, -1.3081065 ,  2.792893  ,  0.5520507 ,  3.2440302 ,
#           2.9181302 ],
#         [-0.9843089 ,  0.86466336, -0.12107177, -0.28926843,  0.2183544 ,
#          -1.4175634 , -0.30899626, -0.33393598,  0.24914798, -0.63284546,
#           0.36110705],
#         [ 1.3141997 ,  0.9148037 , -1.1850352 , -0.8914137 ,  1.1841755 ,
#          -2.646254  , -3.0957925 , -0.5579705 ,  1.2925024 , -2.9607127 ,
#           0.00816942],
#         [-0.88321185,  0.15978207,  0.15651973,  0.29118866,  0.20554128,
#          -1.1634697 , -0.76747775, -0.17252168, -0.98323554,  1.1990409 ,
#          -0.47634283],
#         [ 1.1616219 ,  0.49984503,  0.5497392 , -1.2138289 , -0.16999994,
#           1.6650503 ,  1.1787691 ,  0.03652075, -2.152091  , -0.40738946,
#           3.2268968 ]], dtype=float32),
#  array([-4.0293922 , -2.545799  , -4.952392  , -3.483594  , -0.0278502 ,
#         -3.7624724 ,  1.0170982 , -4.515112  , -1.918096  , -0.54090726,
#         -2.8610861 ], dtype=float32),
#  array([[ 1.2414838 ,  0.28886735,  1.9185294 ,  0.15215074,  1.783785  ,
#           1.8739008 ,  0.03641885],
#         [-0.24694738,  1.1045834 , -3.1215453 , -0.9323424 , -1.9133189 ,
#          -1.299494  , -0.7284752 ],
#         [-2.3311377 , -3.8332775 , -5.416203  , -1.4177763 ,  1.0426205 ,
#          -1.9068342 , -0.9312258 ],
#         [ 0.6682117 , -1.4766997 ,  1.4318959 , -1.2170798 , -1.1612608 ,
#          -2.3683739 , -0.11826964],
#         [-0.5129704 , -0.16207495, -1.1428825 , -0.67289305,  0.23804247,
#          -5.1943913 , -0.9122082 ],
#         [ 0.3085832 , -2.2205412 , -2.216815  , -0.5265509 ,  0.6917337 ,
#          -0.63564557, -1.0040847 ],
#         [ 0.88380975,  0.2981982 ,  0.889382  , -1.0943074 , -1.1633847 ,
#           0.96528065, -1.5553681 ],
#         [-1.6580105 ,  2.4629958 , -5.8894467 ,  0.22038081, -4.2741947 ,
#          -0.23906125, -0.59737587],
#         [ 0.55119306, -0.3468477 , -7.763011  , -0.20009227, -0.6425743 ,
#          -0.30113503, -0.5278147 ],
#         [ 0.33235198,  0.90867096, -3.0301938 , -0.7417922 , -0.07427764,
#           0.6443508 ,  0.08290472],
#         [ 0.19707598,  0.49869323,  0.36380416, -0.41085845, -2.044568  ,
#           1.5499914 , -0.22655231]], dtype=float32),
#  array([ 5.6303024,  2.609196 ,  0.0771718, -0.9209046, -2.9330835,
#          3.034528 , -0.7547167], dtype=float32),
#  array([[-0.01062223, -0.6626577 ,  0.84872293, -1.4166878 , -0.07428798,
#          -0.10747892],
#         [-0.39001122, -0.08715952,  0.5255473 ,  0.03373346, -0.26278305,
#          -0.63403034],
#         [-1.0549623 ,  0.19013855, -0.94993424,  0.6784223 , -0.5375267 ,
#          -0.51062703],
#         [-0.16527648,  0.16314971, -0.09685135, -0.23322533,  0.37104937,
#          -0.7640302 ],
#         [-0.1030177 , -0.6843699 , -0.27087483, -0.31151703, -0.490145  ,
#          -0.51562494],
#         [-0.2740233 , -0.06431348,  1.4928964 ,  0.05254095, -0.0193906 ,
#          -0.22096658],
#         [-0.3792054 ,  0.16055644,  0.17786558, -0.49113342, -0.03031941,
#          -0.57436097]], dtype=float32),
#  array([-0.23906682, -0.44564155,  0.01099979, -1.5874662 , -0.6091002 ,
#         -0.46247256], dtype=float32),
#  array([[ 0.05237806],
#         [ 0.47632635],
#         [-0.40365502],
#         [ 0.00452289],
#         [ 0.04892518],
#         [ 0.09438942]], dtype=float32),
#  array([1.2418727], dtype=float32),
#  array([[ 3.3021793 , -0.01084995,  2.9479823 , -0.58347857,  2.1894305 ,
#           3.0076656 ,  2.286488  ]], dtype=float32),
#  array([ 0.01047036,  0.        , -0.11168485,  0.        , -1.2015947 ,
#         -0.11501162, -0.42124647], dtype=float32),
#  array([[-0.27204335,  2.1699066 , -0.03436303, -2.3786678 , -0.7736033 ,
#          -0.1512329 ],
#         [-0.48422766,  0.2714547 , -0.2680479 , -0.02872777, -0.5063856 ,
#           0.5485817 ],
#         [ 0.5203592 , -0.4734475 ,  0.6731243 , -3.2082093 , -1.8615685 ,
#           0.72219324],
#         [ 0.32199514, -0.63924396,  0.25262755,  0.57292616, -0.45924145,
#          -0.23099515],
#         [ 2.5116508 ,  1.0012825 ,  3.2630422 , -1.3678143 , -1.3193228 ,
#           3.1159813 ],
#         [ 0.48586836, -0.724407  ,  0.43811738, -2.3068123 , -1.9179732 ,
#           0.4782156 ],
#         [ 1.0025673 , -0.6521655 ,  1.040369  , -2.6473565 , -3.0700316 ,
#           0.5915958 ]], dtype=float32),
#  array([-0.15151976, -0.5783887 ,  0.01020785,  0.5712595 ,  0.7007438 ,
#         -0.0591306 ], dtype=float32),
#  array([[ 0.27096987],
#         [ 0.44823343],
#         [ 0.3137754 ],
#         [-1.2867283 ],
#         [-0.8176076 ],
#         [ 0.34881017]], dtype=float32),
#  array([-1.4556895], dtype=float32)]
